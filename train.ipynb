# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (e.g., YOLOv8n for Nano, YOLOv8s for Small)
model = YOLO("yolov8s.pt")  # Replace with yolov8s.pt, yolov8m.pt, etc., for larger models

# Train the model
results = model.train(
    data="./data.yaml",  # Path to your dataset config file
    epochs=15,                  # Number of training epochs
    batch=16,                   # Batch size
    imgsz=640,                  # Image size for training
    device='cpu',                   # GPU (use '0' for single GPU, or 'cpu' for CPU training)
    name="custom_yolov8_model", # Name of the experiment
    workers=4                   # Number of dataloader workers
)
# Out:
# Ultralytics 8.3.22  Python-3.12.4 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-11260H 2.60GHz)
# ...

# %%
# Load a pretrained YOLOv8 model
model = YOLO("yolov8s.pt")  # Options: 'yolov8s.pt', 'yolov8m.pt', etc.

# Train the model
model.train(
    data="/kaggle/input/underwater-plastic-pollution-detection/underwater_plastics/data.yaml",  # Path to YAML file
    epochs=10,                           # Number of epochs
    batch=16,                            # Batch size
    imgsz=640,                            # Image size
    verbose=False  # Suppress unnecessary output
)

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO(r'C:\Users\nagar\Downloads\plastic detection\underwater_plastics\runs\detect\custom_yolov8s_model_50\weights\best (2).pt')

# %%
# Run predictions on a folder of test images
predictions = model.predict(r"C:\Users\nagar\Downloads\plastic detection\underwater_plastics\test\images\GettyImages-1227891345-1000x667_jpg.rf.32ae9a5a4e410851af33ae743636ac1a.jpg", imgsz=640, conf=0.5)  # Adjust confidence threshold if necessary

# Show and visualize the results
for pred in predictions:
    pred.show()  # Display image with bounding boxes and class labels
# Out:
# image 1/1 C:\Users\nagar\Downloads\plastic detection\underwater_plastics\test\images\GettyImages-1227891345-1000x667_jpg.rf.32ae9a5a4e410851af33ae743636ac1a.jpg: 640x640 1 Mask, 191.2ms
# Speed: 8.0ms preprocess, 191.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
