# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 15.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8s.pt")  

# Train the model
results = model.train(
    data="/kaggle/input/underwater-plastic-pollution-detection/underwater_plastics/data.yaml",  # Path to your dataset config file
    epochs=10,                
    batch=16,                   
    imgsz=640,                 
    # device=0,                   
    name="custom_yolov8_model", 
    workers=4                   
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 191MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
model = YOLO("yolov8s.pt")  

results = model.train(
    data="/kaggle/input/underwater-plastic-pollution-detection/underwater_plastics/data.yaml",  # Path to your dataset config file
    epochs=50,                
    batch=16,                  
    imgsz=640,                  
    # device=0,                   
    name="custom_yolov8_model_50", 
    workers=4                   
)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO(r'C:\Users\nagar\Downloads\plastic detection\underwater_plastics\runs\detect\custom_yolov8s_model_50\weights\best (2).pt')

# %%
predictions = model.predict(r"C:\Users\nagar\Downloads\plastic detection\underwater_plastics\test\images\GettyImages-1227891345-1000x667_jpg.rf.32ae9a5a4e410851af33ae743636ac1a.jpg", imgsz=640, conf=0.5)  # Adjust confidence threshold if necessary


for pred in predictions:
    pred.show()
# Out:
# image 1/1 C:\Users\nagar\Downloads\plastic detection\underwater_plastics\test\images\GettyImages-1227891345-1000x667_jpg.rf.32ae9a5a4e410851af33ae743636ac1a.jpg: 640x640 1 Mask, 213.9ms
# Speed: 5.1ms preprocess, 213.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
import matplotlib.pyplot as plt


image_path = r"C:\Users\nagar\Downloads\plastic detection\underwater_plastics\runs\detect\custom_yolov8s_model_50\results.png"  # Replace with your image file path
image = cv2.imread(image_path)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.axis('off')  
plt.title("Results")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


image_path = r"C:\Users\nagar\Downloads\plastic detection\underwater_plastics\runs\detect\custom_yolov8s_model_50\confusion_matrix_normalized.png"  # Replace with your image file path
image = cv2.imread(image_path)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.axis('off')  
plt.title("")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


image_path = r"C:\Users\nagar\Downloads\plastic detection\underwater_plastics\runs\detect\custom_yolov8s_model_50\P_curve.png"  # Replace with your image file path
image = cv2.imread(image_path)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.axis('off')  
plt.title("")
plt.show()
